# %%
import urllib.request
from pprint import pprint
from html_table_parser import HTMLTableParser
import pandas as pd

# %%
def url_get_contents(url):

    # Opens a website and read its
    # binary contents (HTTP Response Body)

    #making request to the website
    url = "https://www.barbadosturfclub.org/entries-for-saturday-12-december-2020-the-david-seale-racing-nite-inaugural-raceday-under-the-lights/"
    req = urllib.request.Request(url=url)
    f = urllib.request.urlopen(req)

    #reading contents of the website
    return f.read()

# %%
url = 'https://www.barbadosturfclub.org/entries-for-saturday-12-december-2020-the-david-seale-racing-nite-inaugural-raceday-under-the-lights/'
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
# defining the html contents of a URL.
xhtml = url_get_contents('Link').decode('utf-8')

# Defining the HTMLTableParser object
p = HTMLTableParser()

# feeding the html contents in the
# HTMLTableParser object
p.feed(xhtml)

# Now finally obtaining the data of
# the table required
pprint(p.tables[0])
# Out:
# [['Race 1 [6:00PM] – 1100M (Turf) – Purse: $18,000 –\xa0 \xa0Saturday, '
#   'December 12, 2020'],
#  ['THE DANCIN DAVID TROPHY (ALLOTTED WEIGHTS RACE)'],
#  ['WEST INDIAN BRED 2-YEAR-OLD MAIDENS'],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['Frm',
#   'PP',
#   'Horse',
#   'Rat',
#   'Days',
#   'A/S',
#   'Eqpt',
#   'Jockey',
#   'Wgt',
#   'Trainer',
#   'Earnings'],
#  ['84',
#   '1',
#   'DE CONKIE MAN',
#   '50',
#   '28',
#   '2/C',
#   '',
#   '',
#   '121',
#   'RPeirce SCM',
#   '$1,480'],
#  ['', '2', 'ROCKIN ROBIN', '50', '', '2/C', '', '', '121', 'RPeirce SCM', '$0'],
#  ['9',
#   '3',
#   'MAKEDA(Res 01)',
#   '45',
#   '28',
#   '2/F',
#   '',
#   '',
#   '116',
#   'RGreene',
#   '$0'],
#  ['', '4', 'PETTICOAT', '45', '', '2/F', '', '', '116', 'EWalcott Jr.', '$0'],
#  ['', '5', 'SARAH(T&T)', '45', '', '2/F', '', '', '116', 'John K', '$0'],
#  ['', '6', 'THUNDER LADY', '45', '', '2/F', '', '', '116', 'PBatson', '$0'],
# ...

# %%
p.tables[0]
# Out:
# [['Race 1 [6:00PM] – 1100M (Turf) – Purse: $18,000 –\xa0 \xa0Saturday, December 12, 2020'],
#  ['THE DANCIN DAVID TROPHY (ALLOTTED WEIGHTS RACE)'],
#  ['WEST INDIAN BRED 2-YEAR-OLD MAIDENS'],
#  ['', '', '', '', '', '', '', '', '', '', ''],
#  ['Frm',
#   'PP',
#   'Horse',
#   'Rat',
#   'Days',
#   'A/S',
#   'Eqpt',
#   'Jockey',
#   'Wgt',
#   'Trainer',
#   'Earnings'],
#  ['84',
#   '1',
#   'DE CONKIE MAN',
#   '50',
#   '28',
#   '2/C',
#   '',
#   '',
#   '121',
#   'RPeirce SCM',
#   '$1,480'],
#  ['',
#   '2',
#   'ROCKIN ROBIN',
#   '50',
#   '',
#   '2/C',
#   '',
#   '',
#   '121',
#   'RPeirce SCM',
#   '$0'],
#  ['9',
#   '3',
#   'MAKEDA(Res 01)',
#   '45',
#   '28',
#   '2/F',
#   '',
#   '',
#   '116',
#   'RGreene',
#   '$0'],
#  ['', '4', 'PETTICOAT', '45', '', '2/F', '', '', '116', 'EWalcott Jr.', '$0'],
#  ['', '5', 'SARAH(T&T)', '45', '', '2/F', '', '', '116', 'John K', '$0'],
#  ['', '6', 'THUNDER LADY', '45', '', '2/F', '', '', '116', 'PBatson', '$0'],
# ...

# %%
races = {}
race_num_list = []
for i in p.tables:
    race_num_list.append((i[0][0].split(" [")[0]))
    print(i[5][2])
# races["Race Number"] = race_num_list
# Out:
# DE CONKIE MAN
# Horse
# Horse
# Horse
# AMANTE
# Horse
# ODYSSEY
# VISIONARY
# Horse

# %%
races
# Out:
# {'Race Number': ['Race 9 [10:00PM] – 1100M (Turf) – Purse: $18,000 –\xa0 \xa0Saturday, December 12, 2020']}

# %%
table = soup.find_all('table')[0]
new_table = pd.DataFrame(columns=range(0,2), index = [0]) # I know the size 
    
row_marker = 0
for row in table.find_all('tr'):
    column_marker = 0
    columns = row.find_all('td')
    for column in columns:
        new_table.iat[row_marker,column_marker] = column.get_text()
        column_marker += 1
    
new_table
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-bb6438409f89> in <module>
#       7     columns = row.find_all('td')
#       8     for column in columns:
# ----> 9         new_table.iat[row_marker,column_marker] = column.get_text()
#      10         column_marker += 1
#      11
#
# ~/opt/anaconda3/envs/webscrape/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#    2192         key = list(self._convert_key(key, is_setter=True))
#    2193         key.append(value)
# -> 2194         self.obj._set_value(*key, takeable=self._takeable)
#    2195
#    2196
#
# ~/opt/anaconda3/envs/webscrape/lib/python3.6/site-packages/pandas/core/frame.py in _set_value(self, index, col, value, takeable)
#    3026         try:
#    3027             if takeable is True:
# -> 3028                 series = self._iget_item_cache(col)
# ...

# %%
table[0]
# Out:
# <table class="tablepress tablepress-id-111 dataTable" id="tablepress-111-no-2">
# <thead>
# <tr class="row-1 odd">
# <th class="column-1" colspan="11"> <p><strong>Race 1</strong>   [6:00PM] – <strong>         1100M (Turf)</strong> – Purse: $18,000 –   Saturday, December 12, 2020</p><br/>
# </th>
# </tr>
# </thead>
# <tbody class="row-hover">
# <tr class="row-2">
# <td class="column-1" colspan="11"> <p><strong>THE DANCIN DAVID TROPHY (ALLOTTED WEIGHTS RACE)</strong></p><br/>
# </td>
# </tr>
# <tr class="row-3">
# <td class="column-1" colspan="11"> <p><strong>WEST INDIAN BRED 2-YEAR-OLD MAIDENS</strong></p><br/>
# </td>
# </tr>
# <tr class="row-4">
# <td class="column-1"></td><td class="column-2"></td><td class="column-3"></td><td class="column-4"></td><td class="column-5"></td><td class="column-6"></td><td class="column-7"></td><td class="column-8"></td><td class="column-9"></td><td class="column-10"></td><td class="column-11"></td>
# </tr>
# <tr class="row-5">
# ...
